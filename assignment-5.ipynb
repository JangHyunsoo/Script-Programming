# %% [markdown]
# # Assignment 5
# ### [정보]
# #### 1) Due Date: 2021년 12월 11일 (토), 23시 59분
#
# #### 2) 제출방법: 수업 홈페이지 하단의 "[숙제 제출 방법]" 참고
#
# #### 3) 내용: 반드시 python code와 수행 결과를 jupyter notebook 내에 작성하여 넣고, 이에 대한 설명 등을 해당 코드 아래에 markdown cell 등에 넣어 기입하시오.
#
# #### 4) 숙제이후 소감 작성: 다음 문제의 답을 모두 작성한 이후에 현재까지 강의를 들은 후의 소감, 숙제를 한 이후의 소감, 또는 전하고자 하는 말 등을 짧막하게라도 좋으니 jupyter notebook 마지막 markdown cell에 함께 작성하여 제출하시오.
#
# #### 5) 반드시 본인 스스로 문제를 해결하세요~~~

# %% [markdown]
# ### [일반 문제]

# %% [markdown]
# ## Problem 1

# %% [markdown]
# 1. 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# #### 설명
# - python에서 클래스는 말 그대로 틀을 변수를 내부적으로 가지고 있으며 이를 연산할 수 있는 메소드를 가지고 있는 것을 말합니다. 마찬가지로 모듈은 파이썬의 하나의 파일로 내부에 있는 변수와 매소드를 할 수 있습니다.
# - 차이점으로는 클래스는 하나의 객체로서 생성(인스터스화)할 수 있지만 모듈은 이를 할 수 없습니다.
# - 또한 모듈은 클래스를 포함할 수 있습니다.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# 2. 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %%
class Person:
    def __init__(self, name):
        self.name = name
    def act(self):
        print(self.name,"\t: doing nothing")
    def printName(self):
        print("Name: ", self.name)

class Student(Person):
    def act(self):
        print(self.name, "\t: studying hard")

class Teacher(Person):
    def act(self):
        print(self.name, "\t: teaching student")
        
person_list = list()
person_list.append(Person("kim"))
person_list.append(Student("jang"))
person_list.append(Teacher("lee"))

for item in person_list:
    item.act()
# Out:
# kim 	: doing nothing
# jang 	: studying hard
# lee 	: teaching student

# %% [markdown]
# ####  설명
# - 다형성이란 다른 클래스에 속한 같은 이름의 인스턴스들이 동일한 메소드 이름으로 호출할 경우 동적으로 선택되어 수행됨을 의미한다.
# - 위 예시를 보면 모두 같은 act 호출하고 있지만 내부적으로는 0번 요소는 Person의 act를 1번 요소는 Student의 act를 2번 요소는 Teacher의 act를 실행하게 된 걸 볼 수 있다.

# %% [markdown]
# ## Problem 3

# %% [markdown]
# 3. 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)
#   - 요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
#     - count: Counter 인스턴스가 지니는 초기 정수 값
#     - step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#
#     > \>\>\> c = Counter(10) <br/>
#     > \>\>\> d = Counter(10, 2) <br/>
#
#   - 요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 \_\_str\_\_() 메소드를 Counter 클래스 내에 구현하시오.
#     > \>\>\> print(c)  <br/>
#     > [Count (step: 1)] 10 <br/>
#     > \>\>\> print(d)  <br/>
#     > [Count (step: 2)] 10 <br/>
#
#   - 요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 Counter 클래스 내에 구현하시오.
#     > \>\>\> c.incr()  <br/>
#     > \>\>\> d.incr()  <br/>
#     > \>\>\> print(c)  <br/>
#     > [Count (step: 1)] 11 <br/>
#     > \>\>\> print(d)  <br/>
#     > [Count (step: 2)] 12 <br/>
#
#   - 요구사항 4. Counter 클래스 내에 관련 메소드를 추가하여 인스턴스 객체를 직접 호출(call)할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때에 내부적으로 incr() 메소드를 호출하는 방법으로 구현하시오.
#     > \>\>\> c()  <br/>
#     > \>\>\> d()  <br/>
#     > \>\>\> print(c)  <br/>
#     > [Count (step: 1)] 12 <br/>
#     > \>\>\> print(d)  <br/>
#     > [Count (step: 2)] 14 <br/>
#
#   - 요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#     > \>\>\> c = c + 5  <br/>
#     > \>\>\> d = d - 5  <br/>
#     > \>\>\> print(c)  <br/>
#     > [Count (step: 1)] 17 <br/>
#     > \>\>\> print(d)  <br/>
#     > [Count (step: 2)] 9 <br/>
#
#   - 요구사항 6. 다음과 같은 관계연산 (>, <, ==)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#     > \>\>\> print(c > 10)  <br/>
#     > True <br/>
#     > \>\>\> print(d > 10) <br/>
#     > False <br/>
#     > \>\>\> print(c < 10)  <br/>
#     > False <br/>
#     > \>\>\> print(d < 10) <br/>
#     > True <br/>
#     > \>\>\> print(c == 17)  <br/>
#     > True <br/>
#     > \>\>\> print(d != 9) <br/>
#     > False <br/>

# %%
class Counter:
    def __init__(self, count = 1, step = 1):
        self.count = count
        self.step = step
        
    def incr(self):
        self.count += self.step
        
    def __str__(self):
        return "[Count (step: {0})] {1}".format(self.step, self.count)
    
    def __call__(self):
        self.incr()
        
    def __add__(self, value):
        if(isinstance(value, int)):
            return Counter(self.count + value, self.step)
        return Counter(self.count, self.step)
    
    def __sub__(self, value):
        if(isinstance(value, int)):
            return Counter(self.count - value, self.step)
        return Counter(self.count ,self.step)
    
    def __radd__(self, value):
        if(isinstance(value, int)):
            return Counter(self.count + value, self.step)
        return Counter(self.count, self.step)
    
    def __rsub__(self, value):
        if(isinstance(value, int)):
            return Counter(value - self.count, self.step)
        return Counter(self.count ,self.step)
    
    def __lt__(self, other):
        if(isinstance(other, int)):
            return self.count > other
        elif(isinstance(other, Counter)):
            return self.count > other.count 
        return False
    
    def __le__(self, other):
        if(isinstance(other, int)):
            return self.count >= other
        elif(isinstance(other, Counter)):
            return self.count >= other.count 
        return False
    
    def __eq__(self, other):
        if(isinstance(other, int)):
            return self.count == other
        elif(isinstance(other, Counter)):
            return self.count == other.count 
        return False
    
c = Counter(10)
d = Counter(10, 2)

print(c != 10)
print(d)
# Out:
# False
# [Count (step: 2)] 10

# %% [markdown]
# ### 설명
# 1. `__init__`을 오버로딩하여 생성자를 정의하였고 count와 step의 default는 모두 1로 하였다.
# 2. `__str__`를 오버로딩하였고 format을 이용하여 Counter를 str로 바꿔주는 내용이다.
# 3. incr는 새로 정의하였고 self.count += self.step을 이용하여 count를 증가시켜주었다.
# 4. `__call__`을 오버로딩하여 위의 c()처럼 사용할 수 있게 만들었고 내부적으로는 self.incr()를 불러 증가시켜주었다.
# 5. (+,-)를 오버로딩하기 위하여 `__sub__`와 `__add__`를 오버로딩하였고 추가적으로 `__rsub__`와 `__radd__`도 정의해주었다.
# 6. (==, >, <, >=, <=)를 오버로딩하기 위하여 `__it__`, `__le__`, `__eq__`을 오버도딩해주었다. 이유는 `__it__`을 만들면 `__gt__`가 `__le__`를 만들면 `__ge__`가 `__eq__`를 정의하면 `__nq__`가 추가적으로 얻을 수 있기 때문에 모두 정의하지 않았다.

# %% [markdown]
# ## Problem 4

# %% [markdown]
# 4. 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 \_\_init\_\_(), \_\_str()\_\_(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.
#
#   - MySet은 집합(Set) 자료형을 정의하려는 의도하에 만들어진 클래스이다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# ### 설명
# 0. 위 클래스는 기존에 있는 list를 상속받아 MySet를 만드는 함수이다. 때문에 list에 있는 기본적인 메소드들을 사용할 수 있다.
# 1. `__init__`은 생성자로 클래스를 통하여 객체를 만들때 불러지는 매직 메소드이다. 현재 클래스의 경우 리스트를 받아 이를 사진의 리스트에 넣고 후에 나온는 eliminate_duplicate을 이용하여 중복된 요소를 지우는 역활을 한다.
# 2. `__str__`은 str()을 이용하여 객체를 부를 경우 문자열로 바꾸기 위하여 불러지는 매직 메소드이다. 여기서는 처음에는 result에 "MySet: {"을 넣어주고 여기에 요소를 하나씩 넣어준다. 이후 마지멕에 들어간 " ,"을 지워주고 "}"를 넣어주기 위하여 result[0:len(result)-2] + "}"를 넣우다. 마지막으로 위에서 만든 result 문자열을 반환해준다.
# 3. 마지막은 eliminate_duplicate이다 이는 위와 다르게 일반적인 정적 메소드이며 정적 메소드는 현재 객체가 없어도 사용할 수 있는 객체이다. 때문에 MySet.eliminate_duplicate(l) 처럼 사용할 수 도 있다. 함수를 설명하자면 self를 받지 않기 때문에 인자로 list를 받아 사용하였다. 함수 안으로 들어가면 임시 객체인 s에 l의 요소를 넣는다. 이때 현재까지의 s에 들어않은 요소만 넣어 중복을 재거한다. 마지막으로는 l에 s를 복사해주고 함수를 마친다.

# %% [markdown]
# ## Problem 5

# %% [markdown]
# 5. 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오.
#
#   - 정답을 각 요구사항별로 입력할 필요 없이 요구사항 3개 전체에 대해 1개의 MySet 클래스 정의 코드를 제시하고 주석등으로 해당 코드를 설명한다.
#   - 요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#     > \>\>\> u = s | t  <br/>
#     > \>\>\> print(u)  <br/>
#     > MySet: {1, 2, 3, 4, 5, 6, 7, 8, 9} <br/>
#
#   - 요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#     > \>\>\> u = s & t  <br/>
#     > \>\>\> print(u)  <br/>
#     > MySet: {2, 3} <br/>
#
#   - 요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#     > \>\>\> s = MySet([1, 2, 3])  <br/>
#     > \>\>\> t = MySet([3, 4, 5])  <br/>
#     > \>\>\> u = s - t  <br/>
#     > \>\>\> print(u)  <br/>
#     > MySet: {1, 2} <br/>

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)
    
    
    def __or__(self, other):
        s = list()
        for e in self:
            s.append(e)
        for e in other:
            s.append(e)
        return MySet(s)
    
    def __and__(self, other):
        s = list()
        for e in other:
            if e in self:
                s.append(e)
        return MySet(s)
    
    def __sub__(self, other):
        s = list()
        for e in self:
            if e not in other:
                s.append(e)
        return MySet(s)
    
if __name__ == "__main__":
    s = MySet([1, 2, 3])
    t = t = MySet([3, 4, 5])
    u = s - t
    print(u)
# Out:
# MySet: {1 ,2}

# %% [markdown]
# ### 설명
# 0. 중복은 생성을 하며 제거가 됨으로 따로 해주지 않았습니다.
# 1. `|`는 `__and__`를 재정의하여 사용하였고 함수 내용은 other의 요소 중 self에 요소가 중복되어 있다면 그것을 s에 넣어두고 최종적으로 나온 s를 이용하여 MySet을 생성하였다.
# 2. `&`는 `__or__`를 재정의하여 사용하였고 함수 내용은 other과 self의 요소를 모두 연결하여 s에 넣어두고 최종적으로 나온 s를 이용하여 MySet을 생성하였다.
# 3. `-`는 `__sub__`를 재정의하여 사용하였고 함수 내용은 self의 요소 중 other에 있는 요소가 중복되어 있지 않다면 그것을 s에 넣어두고 최종적으로 나온 s를 이용하여 MySet을 생성하였다.

# %% [markdown]
# ## Problem 6

# %% [markdown]
# 6. 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.
#
# ```py
# s = MySet([1, 2, 3, 4, 5, 6])
# print(len(s))
# ```
# ```
# > 6
# ```
# ```py
# print(bool(s))
# ```
# ```
# > True
# ```
# ```py
# print(2 in s)
# ```
# ```
# > True
# ```

# %% [markdown]
# ### 설명
# - MySet이 list를 상속하여 사용하고 있기 때문에 기존에 list에 있는 메소드들을 사용할 수 있다.

# %% [markdown]
# ### [Incremental Project 문제]

# %% [markdown]
# #### 1. Assignment 3 & Assignment 4의 Incremental Project 코드를 다시 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오 (CODE REFACTORING!!!).
#   - 1) 새로운 클래스 SearchEngine를 정의하시오.
#     - 이전 숙제에서 고려했던 pickle 모듈 등은 전혀 고려하지 마시오.
#         - 즉, 하드디스크에 저장하고 다시 로드하는 기능은 본 숙제에는 배제하시오.
#
#     - 이전 숙제에서 적용했던 국어/영어 불용어 처리는 적용하시오.
#   <br/>
#   - 2) 생성자에 URL을 0개에서 임의의 개수를 넣을 수 있도록 생성자 인수를 가변인수로 정의하여 각각의 URL을 리스트 자료형에 유지하시오.
#     > \>\>\> w1 = SearchEngine('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com') <br/>
#     > \>\>\> w2 = SearchEngine('http://www.cnn.com', 'http://www.times.com') <br/>
#     > \>\>\> w3 = SearchEngine() <br/>
#   - 3) addUrl() 메소드를 구현하여 인스턴스를 생성한 이후에도 URL을 추가할 수 있도록 한다.
#     - 반드시 1개의 URL을 추가하도록 구현 (즉, 동시에 여러 개의 URL을 추가하는 것은 배제)
#
#     > \>\>\> w1.addUrl('https://github.com')<br/>
#     > \>\>\> w3.addUrl('http://stackoverflow.com')<br/>
#   - 4) removeUrl() 메소드를 구현하여 URL을 삭제할 수 있도록 한다.
#     - 반드시 1개의 URL을 삭제하도록 구현 (즉, 동시에 여러 개의 URL을 삭제하는 것은 배제)
#
#     > \>\>\> w1.removeUrl('http://www.cnn.com')<br/>
#     > \>\>\> w2.removeUrl('http://stackoverflow.com')<br/>
#   - 5) listUrls() 메소드를 구현하여 현재 등록된 모든 URL을 출력하는 기능을 추가
#     > \>\>\> w1.listUrls()<br/>
#     > http://www.times.com <br/>
#     > https://www.amazon.com <br/>
#     > https://github.com <br/>
#   - 6) getWordsFrequency() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전을 반환하시오.
#     - 만약 등록된 URL이 없다면 공백 사전을 반환
#
#     > \>\>\> w1.getWordsFrequency() <br/>
#     > {'hello': 8, 'site': 12, 'world': 2, 'science': 11, 'program': 1, 'python': 1}
#   - 7) getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환하시오.
#
#     > \>\>\> w1.getMaxFreqencyWords() <br/>
#     > {'site': 12} <br/>
#
#     - 최다 출현 단어의 빈도수가 동일한 경우 모두 출력해주어야 함
#
#     > \>\>\> w2.getMaxFreqencyWords() <br/>
#     > {'site': 12, 'science': 12} <br/>
#
#     - 만약 등록된 URL이 없다면 getMaxFreqencyWords()의 반환 값은 None이 되어야 함.
#   - 8) 임의의 단어 1개를 파라미터로 받는 searchUrlByWord() 메소드를 구현하여 유사도가 높은 웹 사이트를 출력하시오.
#     > \>\>\> w1.searchUrlByWord("news")<br/>
#     > http://www.cnn.com <br/>
#
#     - 파라미터로 받은 단어와 유사도가 동일한 URL이 여러 개이면 해당 URL을 모두 출력하시오.

# %% [markdown]
# #### 2. 위 1번 문제에서 정의한 SearchEngine 클래스를 상속하여 SearchEngineWithOrderedWebWords 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 ***오버라이드***하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.
#   - 리스트 내의 각 원소는 단어와 빈도를 쌍으로 지니는 튜플이다.
#   - getWordFrequence() 메소드에 reverse 라는 인자를 만들고 true 또는 false를 인자로 받을 수 있도록 한다.
#     - reverse 인자의 디폴트 값은 false 이며, 기본적으로 내림차순으로 정렬한다.
#     - reverse 인자에 true를 넣으면 오름차순으로 정렬한다.
#
#   > \>\>\> w4 = SearchEngineWithOrderedWebWords('http://www.times.com', 'https://www.amazon.com', 'https://github.com')
#
#   > \>\>\> w4.getWordsFrequency()<br/>
#   > [('site', 12), ('science', 11), ('hello', 8), ('world', 2), ('program', 1), ('python', 1)]
#
#   > \>\>\> w4.getWordsFrequency(reverse=true)<br/>
#   > [('program', 1), ('python', 1), ('world', 2), ('hello', 8), ('science', 11), ('site', 12)]

# %% [markdown]
# #### 3. 다음과 같은 코딩이 가능하도록 SearchEngineWithOrderedWebWords안에 반복자와 관련된 메소드를 추가하시오.
#
# > \>\>\>&nbsp;for i in w4:<br/>
# > \>\>\>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;print(i)<br/>
# > ('site, 12)<br/>
# > ('science', 11)<br/>
# > ('hello', 8)<br/>
# > ('world', 2)<br/>
# > ('program', 1)<br/>
# > ('python', 1)<br/>

# %%
import requests
import googletrans
import functools
import string

class SearchEngine:
    def __init__(self, *args):
        self.urls = []
        self.frequencys = dict() 
        for url in args:
            print(url, "complete.")
            self.addUrl(url)

    def addUrl(self, url):
        if(url not in self.urls):
            self.urls.append(url)
            self.frequencys[url] = SearchEngine.makeFrequency(url)
    
    def removeUrl(self, url):
        if(url in self.urls):
            self.urls.remove(url)
            del self.frequencys[url]
    
    def getFrequency(self, url):
        if(url in self.urls):
            return self.frequencys[url]
        return None
    
    def updateSource(self):
        frequencys.clear()
        for url in urls:
            self.frequencys[url] = SearchEngine.makeFrequency(url)
    
    def listUrl(self):
        for s in self.urls:
            print(s)
    
    def getWordsFrequency(self):
        total_frequencys = dict()
        for value in self.frequencys.values():
            for word, freq in value.items():
                if(word in total_frequencys):
                    total_frequencys[word] += freq
                else: 
                    total_frequencys[word] = freq
        
        return total_frequencys
    
    def getMaxWordsFrequency(self):
        if(not self.urls): return None
        total_frequencys = self.getWordsFrequency()
        total_frequencys_sorted = sorted(list(total_frequencys.items()), key=lambda x: x[1], reverse=True)
        total_frequencys_max = { k:v for k, v in total_frequencys_sorted if v == total_frequencys_sorted[0][1]}
        return total_frequencys_max
    
    def searchUrlByWord(self, search_key):
        search_dict = list(SearchEngine.searchBySearchKey(search_key,self.frequencys).items())
        print("*" * 10, "Search", "*" * 10)
        for url, info in search_dict:
            if search_dict[0][1][0] == info[0] and search_dict[0][1][1] == info[1]:
                print(url)
        
    
    @staticmethod
    def makeFrequency(url):
        source_html = requests.get(url).text
        source_removeTag = SearchEngine.removeHtmlTag(source_html)
        source_removePunctuation = SearchEngine.removePunctuation(source_removeTag)
        source_removeStopword = SearchEngine.removeStopword(source_removePunctuation)
        result = SearchEngine.getFrequency(source_removeStopword)
        return result
    
    @staticmethod
    def searchBySearchKey(search_key, frequencys):
        search_key = SearchEngine.makeKeyList(list(search_key.split()))
        dict_list = {url:(0,0,0) for url in frequencys.keys()}
    
        for key in search_key:
            for url, result in frequencys.items():
                now_dict = SearchEngine.makeDist(key, result)
                dict_list[url] = now_dict if dict_list[url][0] <= now_dict[0] else dict_list[url]
        
        dict_list = { k:v for k, v in sorted(dict_list.items(),key=lambda item: item[1], reverse=True)}
        return dict_list
    
    @staticmethod
    def sub(s, l, r):
        origin_l, tmp1 = s.split(l,1)
        tmp2, origin_r = tmp1.split(r,1)
        return origin_l + " " + origin_r
    
    @staticmethod
    def removeHtmlTag(source):
        
        # 주석 삭제
        while source.find("//<") != -1:
            source = SearchEngine.sub(source, "//<", ">")
    
        # 요소내부에서 앵커요소 나오는 경우가 있는데 어떻게 처리해야할지 모르겠습니다.
        # 예시. <a href=\" < url > https://gallery.v.daum.net/p/premium/excavation/cSCjAyizEy</url>\" class=\"link_thumb photo_pic1\" data-tiara-action-name=\"오늘의 포토_데이터 운영_하단 썸네일\" data-tiara-layer=\"thumbnail\">
        while source.find("<url>") != -1:
            source = SearchEngine.sub(source, "<url>","</url>")
            
        while source.find("<text>") != -1:
            source = SearchEngine.sub(source, "<text>","</text>")
            
        # <script> 삭제
        while source.find("<script") != -1:
            source = SearchEngine.sub(source, "<script", "</script>")
        
        # <style> 삭제
        while source.find("<style") != -1:
            source = SearchEngine.sub(source, "<style", "</style>")
    
        cursor = source
    
        while cursor.find("<") != -1:
            cursor = SearchEngine.sub(cursor,"<",">")
        
        cursor = cursor.replace("\t","")
        cursor = cursor.replace("\n","")
        cursor = cursor.replace("\r","")
        result = cursor.split(' ')
        
        for _ in range(result.count('')):
            result.remove('')
        
        return result
    
    @staticmethod
    def removePunctuationInString(s):
        for token in string.punctuation:
            s = s.replace(token,"");
        return s

    @staticmethod
    def removePunctuation(s):
        result = list(map(SearchEngine.removePunctuationInString, s))     
        
        for _ in range(result.count('')):
            result.remove('')
        
        return result
    
    @staticmethod
    def lower_all(s):
        return ''.join(map(lambda x: x.lower() if x.isalpha() else x, [c for c in s]))
    
    @staticmethod
    def removeStopwordKorean(l):
        sw = requests.get("https://raw.githubusercontent.com/stopwords-iso/stopwords-ko/master/stopwords-ko.txt").text.split()
        return list(filter(lambda s: not s in sw, l))
    
    @staticmethod
    def removeStopwordEnglish(l):
        sw = requests.get("https://raw.githubusercontent.com/JangHyunsoo/Script-Programming/master/stopword.txt").text.split()
        return list(filter(lambda s: not SearchEngine.lower_all(s) in sw, l))
    
    @staticmethod
    def removeStopword(l):
        l = SearchEngine.removeStopwordKorean(l)
        l = SearchEngine.removeStopwordEnglish(l)
        return l
    
    @staticmethod
    def getFrequency(l):
        d_result = {item : 0 for item in l}
        for item in l:
            d_result[item] += 1
    
        # d_result = {k:v for k,v in sorted(list(d_result.items()), key=lambda x: x[1], reverse=True)}
      
        return d_result
    
    @staticmethod
    def makeData(s):
        return getFrequency(removePunctuation(getWord(requests.get(s).text)))
    
    @staticmethod
    def makeDistWithString(key_origin, s):
        dict_ilst = [1 / float(2 ** (i + 1)) for i in range(len(key_origin))]
        max_dict = 0
        lower_s = SearchEngine.lower_all(s)
        
        for i in range(len(key_origin)):
            key = key_origin[i:]
            now_dict = functools.reduce(lambda x,y: x+y,dict_ilst[i:])
            idx = lower_s.find(SearchEngine.lower_all(key))
            cal_len = float(len(key)) / len(s)
            cal_idx = 1 / (1 + idx)  if idx != -1 else 0
            cal_result = float(cal_idx) * float(cal_len) * float(now_dict)
            max_dict = max_dict if max_dict > cal_result else cal_result
        
        for i in range(1, len(key_origin)):
            key = key_origin[:i]
            now_dict = functools.reduce(lambda x,y: x+y,dict_ilst[i:])
            idx = lower_s.find(SearchEngine.lower_all(key))
            cal_len = float(len(key)) / len(s)
            cal_idx = 1 / (1 + idx)  if idx != -1 else 0 
            cal_result = float(cal_idx) * float(cal_len) * float(now_dict)
            max_dict = max_dict if max_dict > cal_result else cal_result
        
        return (s, max_dict)
        
    @staticmethod
    def makeDist(key_origin, d):
        l = [k for k in d.keys()]
        max_dict = -1
        max_word = " "
    
        for s in l:
            now_word, now_dict = SearchEngine.makeDistWithString(key_origin, s)
            if max_dict < now_dict:
                max_dict = now_dict
                max_word = now_word 
            
        return (max_dict, d[max_word], max_word)
    
    @staticmethod
    def translateList(key_list):
        translator = googletrans.Translator()
        ret = [text for key in key_list for text in list(translator.translate(key, dest='en').text.split())]
        return ret
    
    @staticmethod
    def makeKeyList(key_list):
        ret_list = key_list[:]
        ret_list += SearchEngine.translateList(key_list)
        ret_list = SearchEngine.removeStopword(ret_list)
        return ret_list
        

w1 = SearchEngine("https://animal-crossing.com/", "https://www.python.org/", "https://www.notion.so/", "https://aws.amazon.com/", "https://www.billboard.com/")

# w1.addUrl("https://www.naver.com")
# w1.removeUrl("https://www.naver.com")
# w1.listUrl()
# w1.searchUrlByWord("naver")
# Out:
# https://animal-crossing.com/ complete.
# https://www.python.org/ complete.
# https://www.notion.so/ complete.
# https://aws.amazon.com/ complete.
# https://www.billboard.com/ complete.

# %%
class SearchEngineWithOrderedWebWords(SearchEngine):
    def getWordsFrequency(self, reverse=False):
        total_frequencys = super().getWordsFrequency()
        total_frequencys = {k:v for k,v in sorted(list(total_frequencys.items()), key=lambda x: x[1], reverse= not reverse)}
        return total_frequencys
    
    def __iter__(self):
        self.iter_total_frequencys = [item for item in self.getWordsFrequency().items()]
        self.iter_curr = 0
        self.iter_end = len(self.iter_total_frequencys)
        return self
    
    def __next__(self):
        if(self.iter_curr < self.iter_end):
            result = self.iter_total_frequencys[self.iter_curr]
            self.iter_curr += 1
            return result
        else:
            raise StopIteration

w1 = SearchEngineWithOrderedWebWords("https://animal-crossing.com/", "https://www.python.org/", "https://www.notion.so/", "https://aws.amazon.com/", "https://www.billboard.com/")

# print(w1.getWordsFrequency())
 
# for i in w1:
#     print(i)
# Out:
# https://animal-crossing.com/ complete.
# https://www.python.org/ complete.
# https://www.notion.so/ complete.
# https://aws.amazon.com/ complete.
# https://www.billboard.com/ complete.
# ...

# %% [markdown]
# ### 설명
# `SearchEngine`
# 1. 생성자는 `__init__`를 통하여 만들었고 url를 `*args`를 통하여 받아 아래에서 설명한 addUrl를 통하여 하나씩 추가해주었다.
# 2. `addUrl`은 urls에 str형태로 url이 없으면 추가해주고 이에 맞는 freq를 dictionary<url, freq>의 형태로 frequencys에 넣어주었다. 이때 과거에 frequency를 만들어주는 함수를 한 번에 부르기 위하여 makeFrequency를 static함수로 만들고 호출해주었다.
# 3. `removeUrl`도 마찬가지로 urls에서 url이 있으면 지워주고 frequencys에서도 삭제해준다.
# 4. 개인적으로 만든 updateSource는 freq 즉 웹의 데이터가 바뀐 것을 적용하기 위하여 update해주는 함수이다.
# 5. `listUrl`은 urls의 데이터를 출력해준다.
# 6. `getWordsFrequency`는 위에서 생성된 frequencys를 전부 더하여 만들어주었다.
# 7. `getMaxWordsFrequency`는 위의 `getWordsFrequency` 부른 뒤 items로 바꾼 후 sorting하여 0번 인덱스의 값과 같은 값을 dictonary에 넣어 반환해주었다.
# 8. `searchUrlByWord`는 이전에 만든 search에 관련된 함수를 통하여 유사도를 검사하여 정보들 만들어내고 이 (유사도, 빈도, 문자) 중 빈도가 가장 큰것과 같은 url를 출력하기 위하여 sorting 후 0번 인덱스와 비교하였다. 이때 staticmethod를 만들어 이전에 문자 자르기, 번역하기, 불사전 처리 등을 한 후 유사도를 계산하여 반환해준다.
#
# `SearchEngineWithOrderedWebWords`
# 1. `__init__`은 바뀌는게 없어 따로 overriding하지 않았다.
# 2. `getWordsFrequency`는 인자로 reserve를 주었고 기본으로는 False이다. 함수 내용은 super에 `getWordsFrequency`를 불러 total_freq를 생성해주고 이를 reverse에 따라 sorting하여 반환해주었다.
# 3. 마지막으로 iterator를 사용할 수 있게 바꾸기 위하여 `__iter__`에서는 iter_total_frequencys에 getWordsFrequency()를 items를 통하여 만들어 주었고 현제 보고 있는 값을 알기위하여 iter_curr라는 idx를 생성해주었다. iter_end에는 iter_total_frequencys의 크기를 넣어 언제 오류를 발산하면 되는지 알려주었다. `__next__`에는 현제 iter_curr의 값을 리턴해주고 iter_curr를 하나씩 증가시킨다. 만약 iter_curr가 iter_end와 같아지면 오류를 발산해주었ㄷ.

# %% [markdown]
# ## 느낀점
# 1. 한 학기 동안 일종의 모듈을 만들어 보았는데 여려운 부분도 많았지만 배울 수 있었던게 많았다.
# 2. 파이썬이 알고리즘이나 간단한 프로그램에 쉽게 사용될 수 있는 이유를 확실히 할 수 있었던 것 같다.
# 3. 파이썬은 메모리를 신경쓰지 않아도 된다고 생각하던 나의 생각이 바뀌었던 것 같다.
# 4. 코드가 더럽고 주석도 없어 읽기 힘드셨을 텐데 죄송하고 한 학기 정말 고생하셨습니다.^^
